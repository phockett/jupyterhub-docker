# %% [markdown]
# # Quick env test notebook

# %%
from platform import python_version

print(python_version())
# Out:
# 3.9.5

# %%
# Test ePSproc import
import epsproc as ep
# Out:
# * sparse not found, sparse matrix forms not available.
# * natsort not found, some sorting functions not available.
# * plotly not found, plotly plots not available.
# * pyevtk not found, VTK export not available.

# %%
# Check conda packages
# !conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       1_gnu    conda-forge
# alembic                   1.6.5              pyhd8ed1ab_0    conda-forge
# altair                    4.1.0                      py_1    conda-forge
# anyio                     3.2.1            py39hf3d152e_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# argon2-cffi               20.1.0           py39h3811e60_2    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrs                     21.2.0             pyhd8ed1ab_0    conda-forge
# babel                     2.9.1              pyh44b312d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# ...

# %%
# Check conda envs
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /opt/conda

# %%
# Check Jupyter workspaces
print("Home dir")
# !ls ~/.jupyter/lab/workspaces

# https://stackoverflow.com/questions/52656747/how-can-i-list-all-existing-workspaces-in-jupyterlab
print("\nFrom metadata")
import os, glob, json
for fname in glob.glob(os.path.join(os.environ['HOME'], ".jupyter/lab/workspaces/*")):
     with open (fname, "r") as read_file:
         print (json.load(read_file)['metadata']['id'])
# Out:
# Home dir
# auto-m-6bf5.jupyterlab-workspace  default-37a8.jupyterlab-workspace
#
# From metadata
# default
# auto-m
